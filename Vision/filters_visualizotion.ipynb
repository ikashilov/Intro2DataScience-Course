# %% [markdown]
# # Visualizarion Convolutional Filters

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('data/rose.png')
plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
img.shape
# Out:
# (225, 300, 4)

# %%
def visualize_img(model, img):
    img_batch = np.expand_dims(img, axis=0) # + 1 dim
    conv_img = model.predict(img_batch)     # predict
    conv_img = np.squeeze(conv_img, axis=0) # - 1 dim
    #conv_img = conv_img.reshape(conv_img.shape[:2]) #for what?
    plt.imshow(conv_img)

# %%
model = Sequential()
model.add(Convolution2D(filters=3,    # number of filter layers
                        kernel_size=(3,3),
                        input_shape=img.shape))
# Lets activate then pool!
model.add(Activation('relu'))
#model.add(MaxPooling2D(pool_size=(5,5)))

visualize_img(model, img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
